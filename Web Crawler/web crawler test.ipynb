# %%
import requests

res = requests.get("https://shopee.tw/undefined_xhdpi")

print(res.text)
# Out:
# <!DOCTYPE html> <html> <head> <link rel="preconnect" href="//cf.shopee.tw/" /> <link rel="preconnect" href="//cdngarenanow-a.akamaihd.net/shopee/" /> <link rel="preconnect" href="//cv.shopee.tw/" /> <meta charset="utf-8" /> <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=no" /> <meta name="shopee:git-sha" content="829e2ed43676992904e9b4cc43bdef79f3809ae4"> <meta name="shopee:version" content="rw-v3.18.2"> <script> window.__LOCALE__ = 'TW'; window.__ENV__ = 'live'; window.__HYBRID_GREYSCALE__ = '{"percentage":100}'; window.__TRANSIFY_MAPPING__ = {"id-live":"1569837170","en-live":"1569837152","ms-my-live":"1569837159","zh-hans-live":"1569837165","zh-hant-live":"1569837161","th-live":"1569837167","vi-live":"1569903639","format":"json"}; </script> <script> function isModernBrowser() { return !!window.fetch && !!Object.values && !!Object.entries; } function loadScript(src) { var js = document.createElement('script'); js.s
# ...
